# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset_2019041.csv',header=None)

# %%
"""
accelerometer data 100Hz

x,y,z,timestamp,activty,user

The user presses a button before and after he completed an activity. So it's better to remove some data in the beginning and the end of an activity. Or a percentage of the activity if the activity is very short. 


user mapping:
        "mirko.arnold": 1,
        "ali.reza.jafarian": 2,
        "dimitri.hauri": 3,
        "fee.riebeling": 4,
        "anina.zingg": 5,
        "nicole.lucrezia": 6,
        "karolina.klucznik": 7


activities:
        "Ankleiden": 1,    wear clothes
        "Auto fahren": 2,  drive  
        "Bett machen": 3,  sleep
        "Briefkasten leeren": 4,   empty mailbox
        "Buch oder Zeitschrift lesen": 5,   read book
        "Computerarbeit": 6,  operate computer
        "Einkäufe ausräumen": 7,  clear shopping
        "Einkaufen": 8,   shopping
        "Entkleiden": 9,    undress
        "Essen": 10,  eat
        "Gehen": 11,   walk
        "Geschirrwaschmaschine ausräumen": 12,  Clean up the dishwashing machine   
        "Geschirrwaschmaschine einräumen": 13,  Put in the dishwashing machine
        "Kochen": 14, Cook
        "Lift fahren": 15,   Drive a lift
        "Mobile benutzen und surfen oder chatten": 16, Use mobile and surf or chat
        "Putzen": 17,    ploish shoes
        "TV schauen": 18,   watch TV
        "Zähne putzen": 19   Brush teeth

"""
# Out:
# '\naccelerometer data 100Hz\n\nx,y,z,timestamp,activty,user\n\nThe user presses a button before and after he completed an activity. So it\'s better to remove some data in the beginning and the end of an activity. Or a percentage of the activity if the activity is very short. \n\n\nuser mapping:\n        "mirko.arnold": 1,\n        "ali.reza.jafarian": 2,\n        "dimitri.hauri": 3,\n        "fee.riebeling": 4,\n        "anina.zingg": 5,\n        "nicole.lucrezia": 6,\n        "karolina.klucznik": 7\n\n\nactivities:\n        "Ankleiden": 1,    wear clothes\n        "Auto fahren": 2,  drive  \n        "Bett machen": 3,  sleep\n        "Briefkasten leeren": 4,   empty mailbox\n        "Buch oder Zeitschrift lesen": 5,   read book\n        "Computerarbeit": 6,  operate computer\n        "Einkäufe ausräumen": 7,  \n        "Einkaufen": 8,   shopping\n        "Entkleiden": 9,    undress\n        "Essen": 10,  eat\n        "Gehen": 11,   walk\n        "Geschirrwaschmaschine ausräumen": 12,  Clean up the dishwashing machine   \n        "Geschirrwaschmaschine einräumen": 13,  Put in the dishwashing machine\n        "Kochen": 14, Cook\n        "Lift fahren": 15,   Drive a lift\n        "Mobile benutzen und surfen oder chatten": 16, Use mobile and surf or chat\n        "Putzen": 17,    ploish shoes\n        "TV schauen": 18,   watch TV\n        "Zähne putzen": 19   Brush teeth\n\n'

# %%
df.head()
# Out:
#           0         1         2                        3   4  5
# 0 -0.951225 -0.399994  0.022216  2019-03-26 07:30:10.003  10  6
# 1 -0.951225 -0.399994  0.022216  2019-03-26 07:30:10.012  10  6
# 2 -0.951225 -0.349995  0.022216  2019-03-26 07:30:10.022  10  6
# 3 -0.951225 -0.399994  0.022216  2019-03-26 07:30:10.032  10  6
# 4 -0.951225 -0.399994 -0.022228  2019-03-26 07:30:10.041  10  6

# %%
df.columns = ['x', 'y' , 'z' , 'timestamp' , 'activity' , 'user']

# %%
df.head()
# Out:
#           x         y         z                timestamp  activity  user
# 0 -0.951225 -0.399994  0.022216  2019-03-26 07:30:10.003        10     6
# 1 -0.951225 -0.399994  0.022216  2019-03-26 07:30:10.012        10     6
# 2 -0.951225 -0.349995  0.022216  2019-03-26 07:30:10.022        10     6
# 3 -0.951225 -0.399994  0.022216  2019-03-26 07:30:10.032        10     6
# 4 -0.951225 -0.399994 -0.022228  2019-03-26 07:30:10.041        10     6

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
print('Shape of the data set: ' + str(df.shape))
# Out:
# Shape of the data set: (23069658, 6)

# %%
#check for missing values
Temp = pd.DataFrame(df.isnull().sum())
Temp.columns = ['Sum']
print('Amount of rows with missing values: ' + str(len(Temp.index[Temp['Sum'] > 0])) )
# Out:
# Amount of rows with missing values: 0

# %%
df.head()
# Out:
#           x         y         z               timestamp  activity  user
# 0 -0.951225 -0.399994  0.022216 2019-03-26 07:30:10.003        10     6
# 1 -0.951225 -0.399994  0.022216 2019-03-26 07:30:10.012        10     6
# 2 -0.951225 -0.349995  0.022216 2019-03-26 07:30:10.022        10     6
# 3 -0.951225 -0.399994  0.022216 2019-03-26 07:30:10.032        10     6
# 4 -0.951225 -0.399994 -0.022228 2019-03-26 07:30:10.041        10     6

# %%
df.tail()
# Out:
#                  x         y         z               timestamp  activity  user
# 23069653 -0.799212  0.300781 -0.357572 2019-04-10 08:14:49.959         6     7
# 23069654 -0.814960  0.285156 -0.345451 2019-04-10 08:14:49.969         6     7
# 23069655 -0.822834  0.277344 -0.337371 2019-04-10 08:14:49.979         6     7
# 23069656 -0.834645  0.265625 -0.333330 2019-04-10 08:14:49.989         6     7
# 23069657 -0.846456  0.257812 -0.321209 2019-04-10 08:14:49.999         6     7

# %% [markdown]
# # Data Points Per User

# %%
data_points_per_user = df.groupby(['user']).count()

# %%
data_points_per_user.plot.bar(y='x')

# %% [markdown]
# # Activities Per User
#
# 1. wear clothes
# 2. drive
# 3. sleep
# 4. empty mailbox
# 5. read book
# 6. operate computer
# 7. clear shopping
# 8. shopping
# 9. undress
# 10. eat
# 11. walk
# 12. Clean up the dishwashing machine
# 13. Put in the dishwashing machine
# 14. Cook
# 15. Drive a lift
# 16. Use mobile and surf or chat
# 17. ploish shoes
# 18. watch TV
# 19. Brush teeth

# %%
activites_per_user = df.groupby(['user','activity']).count()

# %%
activites_per_user
# Out:
#                      x        y        z  timestamp
# user activity
# 1    1            4045     4045     4045       4045
#      3            3969     3969     3969       3969
#      4            4065     4065     4065       4065
#      6         1762439  1762439  1762439    1762439
#      7           16240    16240    16240      16240
#      8           58788    58788    58788      58788
#      10         262835   262835   262835     262835
#      11          40528    40528    40528      40528
#      14          46606    46606    46606      46606
#      17          16214    16214    16214      16214
#      19          24301    24301    24301      24301
# 2    1           14218    14218    14218      14218
#      3           26308    26308    26308      26308
#      6         1568162  1568162  1568162    1568162
#      8           58644    58644    58644      58644
#      9           10140    10140    10140      10140
#      10         834289   834289   834289     834289
#      11         200201   200201   200201     200201
#      14         165641   165641   165641     165641
#      17         191719   191719   191719     191719
#      18        4752919  4752919  4752919    4752919
#      19          70701    70701    70701      70701
# 3    1           58118    58118    58118      58118
#      3            8299     8299     8299       8299
#      4            6724     6724     6724       6724
#      5          257087   257087   257087     257087
#      6          903652   903652   903652     903652
#      7          125903   125903   125903     125903
#      8          830006   830006   830006     830006
#      9           22669    22669    22669      22669
# ...                ...      ...      ...        ...
# 6    4            4181     4181     4181       4181
#      5          194404   194404   194404     194404
#      6          677107   677107   677107     677107
#      7           10324    10324    10324      10324
#      8           41430    41430    41430      41430
#      9            4137     4137     4137       4137
#      10         150720   150720   150720     150720
#      11         147513   147513   147513     147513
#      13          37210    37210    37210      37210
#      14         121925   121925   121925     121925
#      15           4140     4140     4140       4140
#      16          82748    82748    82748      82748
#      17         103254   103254   103254     103254
#      19          45479    45479    45479      45479
# 7    1            4062     4062     4062       4062
#      2          257858   257858   257858     257858
#      3            4042     4042     4042       4042
#      5          143226   143226   143226     143226
#      6          100756   100756   100756     100756
#      7           10097    10097    10097      10097
#      8           82715    82715    82715      82715
#      10          64557    64557    64557      64557
#      11          40579    40579    40579      40579
#      12           4039     4039     4039       4039
#      13           4054     4054     4054       4054
#      14          46428    46428    46428      46428
#      15           4038     4038     4038       4038
#      16         119405   119405   119405     119405
#      17          28318    28318    28318      28318
#      19          10102    10102    10102      10102
#
# [84 rows x 4 columns]

# %% [markdown]
# ## Count of activities of  user:1 Mirko Arnold
#
# Arnold has spent more time operating computer.

# %%
activities_user_1 = df.loc[df['user']==1].groupby(['activity']).count()['x']
activities_user_1.plot.bar()

# %%
total = activities_user_1.shape[0]
# Out:
#                 x        y        z  timestamp     user
# activity
# 1            4045     4045     4045       4045     4045
# 3            3969     3969     3969       3969     3969
# 4            4065     4065     4065       4065     4065
# 6         1762439  1762439  1762439    1762439  1762439
# 7           16240    16240    16240      16240    16240
# 8           58788    58788    58788      58788    58788
# 10         262835   262835   262835     262835   262835
# 11          40528    40528    40528      40528    40528
# 14          46606    46606    46606      46606    46606
# 17          16214    16214    16214      16214    16214
# 19          24301    24301    24301      24301    24301

# %% [markdown]
# ## Count of activities of  user:2 Ali Reza Jafarian
#
# Jafarian has spent mpre time watching TV.

# %%
## Count of activities of  user:2

activities_user_2 = df.loc[df['user']==2,:].groupby(['activity']).count()
activities_user_2.plot.bar(y='x')

# %% [markdown]
# ## Count of activities of  user:3 Dimitri Hauri
# Hauri has spent more time operating computer, shopping and eating.

# %%
## Count of activities of  user:3

activities_user_3 = df.loc[df['user']==3,:].groupby(['activity']).count()
activities_user_3.plot.bar(y='x')

# %% [markdown]
# ## Count of activities of  user:4 Fee Riebeling
#
# Riebeling has spent more time operating computer and walking

# %%
## Count of activities of  user:4

activities_user_4 = df.loc[df['user']==4,:].groupby(['activity']).count()
activities_user_4.plot.bar(y='x')

# %% [markdown]
# ## Count of activities of  user:5 Anina Zingg
#
# Zingg has spent more time driving, walking and polishing shoes.

# %%
## Count of activities of  user:5

activities_user_5 = df.loc[df['user']==5,:].groupby(['activity']).count()
activities_user_5.plot.bar(y='x')

# %% [markdown]
# ## Count of activities of  user:6 Nicole Lucrezia
#
# Lucrezia has done almost every activity and has spent more time opearting computer.

# %%
## Count of activities of  user:6

activities_user_6 = df.loc[df['user']==6,:].groupby(['activity']).count()
activities_user_6.plot.bar(y='x')

# %% [markdown]
# ## Count of activities of  user:7 Karolina Klucznik
#
# Klucznik has done almost every activity and has spent more time driving.

# %%
## Count of activities of  user:7

activities_user_7 = df.loc[df['user']==7,:].groupby(['activity']).count()
activities_user_7.plot.bar(y='x')

# %%
df = df.set_index(df['timestamp'])

# %%
df.head()
# Out:
#                                 x         y         z               timestamp  \
# timestamp
# 2019-03-26 07:30:10.003 -0.951225 -0.399994  0.022216 2019-03-26 07:30:10.003
# 2019-03-26 07:30:10.012 -0.951225 -0.399994  0.022216 2019-03-26 07:30:10.012
# 2019-03-26 07:30:10.022 -0.951225 -0.349995  0.022216 2019-03-26 07:30:10.022
# 2019-03-26 07:30:10.032 -0.951225 -0.399994  0.022216 2019-03-26 07:30:10.032
# 2019-03-26 07:30:10.041 -0.951225 -0.399994 -0.022228 2019-03-26 07:30:10.041
#
#                          activity  user
# timestamp
# 2019-03-26 07:30:10.003        10     6
# 2019-03-26 07:30:10.012        10     6
# 2019-03-26 07:30:10.022        10     6
# 2019-03-26 07:30:10.032        10     6
# 2019-03-26 07:30:10.041        10     6

# %%
tmp = df.loc['2019-03-26']

# %%
tmp.tail()
# Out:
#                                 x         y         z               timestamp  \
# timestamp
# 2019-03-26 22:25:49.959  0.121944  0.049999 -0.466669 2019-03-26 22:25:49.959
# 2019-03-26 22:25:49.968  0.121944  0.099998 -0.288893 2019-03-26 22:25:49.968
# 2019-03-26 22:25:49.978  0.073164  0.099998 -0.200005 2019-03-26 22:25:49.978
# 2019-03-26 22:25:49.988  0.073164  0.149998 -0.200005 2019-03-26 22:25:49.988
# 2019-03-26 22:25:49.997  0.073164  0.099998 -0.333337 2019-03-26 22:25:49.997
#
#                          activity  user
# timestamp
# 2019-03-26 22:25:49.959         9     6
# 2019-03-26 22:25:49.968         9     6
# 2019-03-26 22:25:49.978         9     6
# 2019-03-26 22:25:49.988         9     6
# 2019-03-26 22:25:49.997         9     6

# %%
num_rows = tmp[(tmp.activity==10) & (tmp.user == 6)].shape[0]

ten_pc = int((num_rows/100)*10)

tmp = tmp.drop(tmp.index[0:ten_pc])
tmp = tmp.drop(tmp.index[ten_pc:-1])

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
ax = plt.axes(projection='3d')

data_per_act_user = tmp[(tmp.activity==10) & (tmp.user == 6)]

# Data for three-dimensional scattered points
zdata = data_per_act_user['z']
xdata = data_per_act_user['x']
ydata = data_per_act_user['y']
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');

# %%
tmp2 = df.loc['2019-03-28']

# %%
num_rows2 = tmp2[(tmp2.activity==11) & (tmp2.user == 4)].shape[0]

ten_pc2 = int((num_rows2/100)*10)

tmp2 = tmp2.drop(tmp2.index[0:ten_pc2])
tmp2 = tmp2.drop(tmp2.index[ten_pc2:-1])

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
ax = plt.axes(projection='3d')

data_per_act_user2 = tmp2[(tmp2.activity==11) & (tmp2.user == 4)]

# Data for three-dimensional scattered points
zdata = data_per_act_user2['z']
xdata = data_per_act_user2['x']
ydata = data_per_act_user2['y']
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');

# %%
df.groupby('activity').count()
# Out:
#                 x        y        z  timestamp     user
# activity
# 1          247016   247016   247016     247016   247016
# 2          717034   717034   717034     717034   717034
# 3           75115    75115    75115      75115    75115
# 4           14970    14970    14970      14970    14970
# 5          594717   594717   594717     594717   594717
# 6         6612618  6612618  6612618    6612618  6612618
# 7          185255   185255   185255     185255   185255
# 8         1392864  1392864  1392864    1392864  1392864
# 9           36946    36946    36946      36946    36946
# 10        2631187  2631187  2631187    2631187  2631187
# 11        2851784  2851784  2851784    2851784  2851784
# 12           4039     4039     4039       4039     4039
# 13          41264    41264    41264      41264    41264
# 14         592846   592846   592846     592846   592846
# 15           8178     8178     8178       8178     8178
# 16         387547   387547   387547     387547   387547
# 17        1043911  1043911  1043911    1043911  1043911
# 18        5336441  5336441  5336441    5336441  5336441
# 19         295926   295926   295926     295926   295926

# %%
df[(df.user == 1)&(df.activity == 3)]['activity'].count()
# Out:
# 3969

# %%
all_activities = ["Ankleiden","Auto fahren","Bett machen","Briefkasten leeren","Buch oder Zeitschrift lesen","Computerarbeit","Einkäufe ausräumen",
"Einkaufen","Entkleiden","Essen","Gehen","Geschirrwaschmaschine ausräumen","Geschirrwaschmaschine einräumen","Kochen","Lift fahren","Mobile benutzen und surfen oder chatten",
"Putzen","TV schauen","Zähne putzen"]

activities_mapping =  {"Ankleiden": 1,
        "Auto fahren": 2,
        "Bett machen": 3,
        "Briefkasten leeren": 4,
        "Buch oder Zeitschrift lesen": 5,
        "Computerarbeit": 6,
        "Einkäufe ausräumen": 7,
        "Einkaufen": 8,
        "Entkleiden": 9,
        "Essen": 10,
        "Gehen": 11,
        "Geschirrwaschmaschine ausräumen": 12,
        "Geschirrwaschmaschine einräumen": 13,
        "Kochen": 14,
        "Lift fahren": 15,
        "Mobile benutzen und surfen oder chatten": 16,
        "Putzen": 17,
        "TV schauen": 18,
        "Zähne putzen": 19}

def plotStatistics(users=[1,2,3,4,5,6,7], activities=all_activities, offsetInPercent=10):
        print('Generating statistics for given ',len(activities),' activities...\n')
        activities_ids =  [  activities_mapping[x]  for x in all_activities]
        num_unique_activities = df['activity'].nunique()
        print('Number of unique activities performed in total are: ')
        #display(num_unique_activities)
        unique_activities = df.groupby('activity').count()['x']
        print('Unique activities performed in total are: \n',unique_activities)
        unique_activities.plot.bar(y='x')
        
        print('Generating statistics for given ',len(users),' users...\n')
        num_unique_users = df['user'].nunique()
        print('Number of unique users performed in total are: ',num_unique_users)
        unique_users = df.groupby('user').count()['x']
        print('Unique users in total are: \n',unique_users,'\n')
        unique_users.plot.bar(y='x')
        
        

        
plotStatistics()
# Out:
# Generating statistics for given  19  activities...
#
# Number of unique activities performed in total are:
# Unique activities performed in total are:
#  activity
# 1      247016
# 2      717034
# 3       75115
# 4       14970
# 5      594717
# 6     6612618
# 7      185255
# 8     1392864
# 9       36946
# 10    2631187
# 11    2851784
# 12       4039
# 13      41264
# 14     592846
# 15       8178
# 16     387547
# 17    1043911
# 18    5336441
# 19     295926
# Name: x, dtype: int64
# Generating statistics for given  7  users...
#
# Number of unique users performed in total are:  7
# Unique users in total are:
#  user
# 1    2240030
# 2    7892942
# 3    4237162
# 4    3507560
# 5    2628647
# 6    1639041
# 7     924276
# Name: x, dtype: int64

# %%
from IPython.display import display
display(df)
# Out:
#                                 x         y         z               timestamp  \
# timestamp
# 2019-03-26 07:30:10.003 -0.951225 -0.399994  0.022216 2019-03-26 07:30:10.003
# 2019-03-26 07:30:10.012 -0.951225 -0.399994  0.022216 2019-03-26 07:30:10.012
# 2019-03-26 07:30:10.022 -0.951225 -0.349995  0.022216 2019-03-26 07:30:10.022
# 2019-03-26 07:30:10.032 -0.951225 -0.399994  0.022216 2019-03-26 07:30:10.032
# 2019-03-26 07:30:10.041 -0.951225 -0.399994 -0.022228 2019-03-26 07:30:10.041
# 2019-03-26 07:30:10.051 -0.902445 -0.349995 -0.066672 2019-03-26 07:30:10.051
# 2019-03-26 07:30:10.061 -1.000006 -0.399994 -0.022228 2019-03-26 07:30:10.061
# 2019-03-26 07:30:10.070 -1.048786 -0.349995 -0.022228 2019-03-26 07:30:10.070
# 2019-03-26 07:30:10.080 -1.048786 -0.299995  0.066660 2019-03-26 07:30:10.080
# 2019-03-26 07:30:10.090 -1.097567 -0.299995  0.066660 2019-03-26 07:30:10.090
# 2019-03-26 07:30:10.099 -1.146347 -0.399994  0.111104 2019-03-26 07:30:10.099
# 2019-03-26 07:30:10.109 -1.097567 -0.349995  0.066660 2019-03-26 07:30:10.109
# 2019-03-26 07:30:10.119 -1.146347 -0.349995  0.155548 2019-03-26 07:30:10.119
# 2019-03-26 07:30:10.128 -1.048786 -0.349995  0.111104 2019-03-26 07:30:10.128
# 2019-03-26 07:30:10.138 -1.000006 -0.399994  0.155548 2019-03-26 07:30:10.138
# 2019-03-26 07:30:10.148 -0.902445 -0.399994  0.155548 2019-03-26 07:30:10.148
# 2019-03-26 07:30:10.157 -0.951225 -0.349995  0.244436 2019-03-26 07:30:10.157
# 2019-03-26 07:30:10.167 -0.902445 -0.349995  0.199992 2019-03-26 07:30:10.167
# 2019-03-26 07:30:10.177 -0.951225 -0.349995  0.155548 2019-03-26 07:30:10.177
# 2019-03-26 07:30:10.186 -0.902445 -0.399994  0.199992 2019-03-26 07:30:10.186
# 2019-03-26 07:30:10.196 -0.902445 -0.349995  0.333324 2019-03-26 07:30:10.196
# 2019-03-26 07:30:10.206 -0.756104 -0.349995  0.333324 2019-03-26 07:30:10.206
# 2019-03-26 07:30:10.215 -0.804884 -0.349995  0.377769 2019-03-26 07:30:10.215
# 2019-03-26 07:30:10.225 -0.804884 -0.299995  0.377769 2019-03-26 07:30:10.225
# 2019-03-26 07:30:10.235 -0.804884 -0.349995  0.377769 2019-03-26 07:30:10.235
# 2019-03-26 07:30:10.244 -0.853664 -0.349995  0.377769 2019-03-26 07:30:10.244
# 2019-03-26 07:30:10.254 -0.707323 -0.449993  0.466657 2019-03-26 07:30:10.254
# 2019-03-26 07:30:10.264 -0.609762 -0.349995  0.377769 2019-03-26 07:30:10.264
# 2019-03-26 07:30:10.274 -0.609762 -0.349995  0.466657 2019-03-26 07:30:10.274
# 2019-03-26 07:30:10.283 -0.560982 -0.399994  0.511101 2019-03-26 07:30:10.283
# ...                           ...       ...       ...                     ...
# 2019-04-10 08:14:49.711 -0.807086  0.531250 -0.434339 2019-04-10 08:14:49.711
# 2019-04-10 08:14:49.721 -0.799212  0.515625 -0.422218 2019-04-10 08:14:49.721
# 2019-04-10 08:14:49.731 -0.775590  0.515625 -0.410097 2019-04-10 08:14:49.731
# 2019-04-10 08:14:49.741 -0.755905  0.507812 -0.410097 2019-04-10 08:14:49.741
# 2019-04-10 08:14:49.751 -0.736220  0.503906 -0.406057 2019-04-10 08:14:49.751
# 2019-04-10 08:14:49.760 -0.728346  0.503906 -0.406057 2019-04-10 08:14:49.760
# 2019-04-10 08:14:49.770 -0.728346  0.496094 -0.402016 2019-04-10 08:14:49.770
# 2019-04-10 08:14:49.780 -0.728346  0.484375 -0.406057 2019-04-10 08:14:49.780
# 2019-04-10 08:14:49.790 -0.732283  0.468750 -0.414137 2019-04-10 08:14:49.790
# 2019-04-10 08:14:49.800 -0.740157  0.445312 -0.422218 2019-04-10 08:14:49.800
# 2019-04-10 08:14:49.810 -0.740157  0.425781 -0.418178 2019-04-10 08:14:49.810
# 2019-04-10 08:14:49.820 -0.736220  0.417969 -0.426258 2019-04-10 08:14:49.820
# 2019-04-10 08:14:49.830 -0.724409  0.410156 -0.418178 2019-04-10 08:14:49.830
# 2019-04-10 08:14:49.840 -0.724409  0.406250 -0.422218 2019-04-10 08:14:49.840
# 2019-04-10 08:14:49.850 -0.724409  0.406250 -0.426258 2019-04-10 08:14:49.850
# 2019-04-10 08:14:49.860 -0.728346  0.410156 -0.422218 2019-04-10 08:14:49.860
# 2019-04-10 08:14:49.870 -0.724409  0.421875 -0.422218 2019-04-10 08:14:49.870
# 2019-04-10 08:14:49.880 -0.728346  0.417969 -0.426258 2019-04-10 08:14:49.880
# 2019-04-10 08:14:49.890 -0.736220  0.406250 -0.422218 2019-04-10 08:14:49.890
# 2019-04-10 08:14:49.899 -0.744094  0.406250 -0.422218 2019-04-10 08:14:49.899
# 2019-04-10 08:14:49.909 -0.751968  0.406250 -0.414137 2019-04-10 08:14:49.909
# 2019-04-10 08:14:49.919 -0.755905  0.390625 -0.402016 2019-04-10 08:14:49.919
# 2019-04-10 08:14:49.929 -0.755905  0.371094 -0.397976 2019-04-10 08:14:49.929
# 2019-04-10 08:14:49.939 -0.763779  0.343750 -0.393936 2019-04-10 08:14:49.939
# 2019-04-10 08:14:49.949 -0.779527  0.320312 -0.373734 2019-04-10 08:14:49.949
# 2019-04-10 08:14:49.959 -0.799212  0.300781 -0.357572 2019-04-10 08:14:49.959
# 2019-04-10 08:14:49.969 -0.814960  0.285156 -0.345451 2019-04-10 08:14:49.969
# 2019-04-10 08:14:49.979 -0.822834  0.277344 -0.337371 2019-04-10 08:14:49.979
# 2019-04-10 08:14:49.989 -0.834645  0.265625 -0.333330 2019-04-10 08:14:49.989
# 2019-04-10 08:14:49.999 -0.846456  0.257812 -0.321209 2019-04-10 08:14:49.999
#
#                          activity  user
# timestamp
# 2019-03-26 07:30:10.003        10     6
# 2019-03-26 07:30:10.012        10     6
# 2019-03-26 07:30:10.022        10     6
# 2019-03-26 07:30:10.032        10     6
# 2019-03-26 07:30:10.041        10     6
# 2019-03-26 07:30:10.051        10     6
# 2019-03-26 07:30:10.061        10     6
# 2019-03-26 07:30:10.070        10     6
# 2019-03-26 07:30:10.080        10     6
# 2019-03-26 07:30:10.090        10     6
# 2019-03-26 07:30:10.099        10     6
# 2019-03-26 07:30:10.109        10     6
# 2019-03-26 07:30:10.119        10     6
# 2019-03-26 07:30:10.128        10     6
# 2019-03-26 07:30:10.138        10     6
# 2019-03-26 07:30:10.148        10     6
# 2019-03-26 07:30:10.157        10     6
# 2019-03-26 07:30:10.167        10     6
# 2019-03-26 07:30:10.177        10     6
# 2019-03-26 07:30:10.186        10     6
# 2019-03-26 07:30:10.196        10     6
# 2019-03-26 07:30:10.206        10     6
# 2019-03-26 07:30:10.215        10     6
# 2019-03-26 07:30:10.225        10     6
# 2019-03-26 07:30:10.235        10     6
# 2019-03-26 07:30:10.244        10     6
# 2019-03-26 07:30:10.254        10     6
# 2019-03-26 07:30:10.264        10     6
# 2019-03-26 07:30:10.274        10     6
# 2019-03-26 07:30:10.283        10     6
# ...                           ...   ...
# 2019-04-10 08:14:49.711         6     7
# 2019-04-10 08:14:49.721         6     7
# 2019-04-10 08:14:49.731         6     7
# 2019-04-10 08:14:49.741         6     7
# 2019-04-10 08:14:49.751         6     7
# 2019-04-10 08:14:49.760         6     7
# 2019-04-10 08:14:49.770         6     7
# 2019-04-10 08:14:49.780         6     7
# 2019-04-10 08:14:49.790         6     7
# 2019-04-10 08:14:49.800         6     7
# 2019-04-10 08:14:49.810         6     7
# 2019-04-10 08:14:49.820         6     7
# 2019-04-10 08:14:49.830         6     7
# 2019-04-10 08:14:49.840         6     7
# 2019-04-10 08:14:49.850         6     7
# 2019-04-10 08:14:49.860         6     7
# 2019-04-10 08:14:49.870         6     7
# 2019-04-10 08:14:49.880         6     7
# 2019-04-10 08:14:49.890         6     7
# 2019-04-10 08:14:49.899         6     7
# 2019-04-10 08:14:49.909         6     7
# 2019-04-10 08:14:49.919         6     7
# 2019-04-10 08:14:49.929         6     7
# 2019-04-10 08:14:49.939         6     7
# 2019-04-10 08:14:49.949         6     7
# 2019-04-10 08:14:49.959         6     7
# 2019-04-10 08:14:49.969         6     7
# 2019-04-10 08:14:49.979         6     7
# 2019-04-10 08:14:49.989         6     7
# 2019-04-10 08:14:49.999         6     7
#
# [23069658 rows x 6 columns]

# %%
        for user in users:            
            for activity_id in activities_ids:
                activites_per_user[user][activity_id] = df[(df.user == user)&(df.activity == activity_id)]['activity'].count()
